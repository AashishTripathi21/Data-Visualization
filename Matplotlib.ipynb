# %% [markdown]
# ### Matplotlib

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt # Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt.
import numpy as np

### Draw a line in a diagram from position (0,8) to position (5,120):
xpoints = np.array([0, 8])
ypoints = np.array([5, 120])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %%
xpoints = np.array([1, 5])    
ypoints = np.array([5,9])

plt.plot(xpoints, ypoints)
plt.show()                       ### Plotting the x and y points

# %%
ypoints = np.array([4,6])

plt.plot(xpoints, ypoints, 'o')
plt.show()                               ### Plotting the x and y points but by replacing the line with a point

# %%
ypoints = np.array([3, 12, 4, 9])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(ypoints, marker = '*')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Format Strings fmt
# You can use also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
ypoints = np.array([4, 9, 2, 11])

plt.plot(ypoints, 'o:g')          ### The line is replaced with dotted line by using colon : and color of the point is changed to green
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ypoints = np.array([4, 9, 2, 11])

plt.plot(ypoints, marker = 'o', ms = 15)    ### Marker is represented with marker and ms represents marker size
plt.show()

# %%
### You can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers
ypoints = np.array([4, 9, 2, 11])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')   
plt.show()

# %%
ypoints = np.array([4, 9, 2, 11])

plt.plot(ypoints, marker = 'o', ms = 20,mfc='b')    ### mfc represents Marker Fill color
plt.show()

# %%
### Use both the mec and mfc arguments to color of the entire marker
ypoints = np.array([4, 9, 2, 11])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'k', mfc = 'r')    ### Marker Edge Color mec changes the boarder to black with the code k and fill color to red as with code red
plt.show()

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')  ### Color changes using the code

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')

# %%
ypoints = np.array([4, 9, 2, 11])

plt.plot(ypoints, linestyle = 'dotted')   ### Solid line marking the points changes to dotted using the linestyle
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')   ### Solid line changes to dashed line

# %% [markdown]
# The line style can be written in a shorter syntax:
#
# linestyle can be written as ls.
#
# dotted can be written as :.
#
# dashed can be written as --.

# %%
plt.plot(ypoints, ls = ':')    ### Dotted line can be also changed using the colon :

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ypoints = np.array([4, 9, 2, 11])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
plt.plot(ypoints, c = '#4CAF50')     ### Color of the line is changed

# %%
plt.plot(ypoints, c = 'hotpink')      ### Color of the line is changed to hotpink

# %%
### You can use the keyword argument linewidth or the shorter lw to change the width of the line.

### The value is a floating number, in points
ypoints = np.array([4, 9, 2, 11])

plt.plot(ypoints, linewidth = '11.5')
plt.show()

# %%
y1 = np.array([4, 9, 2, 11])
y2 = np.array([6, 3, 7, 12])

plt.plot(y1)
plt.plot(y2)

plt.show()      ### Two plots is plotted using y1 and y2 but x taken as 0,1,2,3 by default

# %% [markdown]
# You can also plot many lines by adding the points for the x- and y-axis for each line in the same plt.plot() function.
#
# (In the examples above we only specified the points on the y-axis, meaning that the points on the x-axis got the the default values (0, 1, 2, 3).)
#
# The x- and y- values come in pairs

# %%
x1 = np.array([1, 3, 5, 7])
y1 = np.array([4, 9, 2, 11])
x2 = np.array([1, 6, 11, 16])
y2 = np.array([7, 3, 8, 12])

plt.plot(x1, y1, x2, y2)
plt.show()                              ### Two plots are plotted as (x1,y1) and (x2,y2)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")              ### Label is given to x axis using function as xlabel("Label you want")
plt.ylabel("Calorie Burnage")            ### Label is given to y axis using function as ylabel("Label you want")
 
plt.show()

# %% [markdown]
# With Pyplot, you can use the title() function to set a title for the plot

# %%
### You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)     ### Title to the plot is given using the title function
plt.xlabel("Average Pulse", fontdict = font2)        ### X-axis label is given using the label function
plt.ylabel("Calorie Burnage", fontdict = font2)      ### Y-axis label is given using the label function

plt.plot(x, y)
plt.show()

# %% [markdown]
# You can use the loc parameter in title() to position the title.
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %% [markdown]
# With Pyplot, you can use the grid() function to add grid lines to the plot

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')    ### Title position can be changed using the location fuction as loc
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")    ### Title is in Center of the plot
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()                        ### Grid is introduced in the plot using grid function

plt.show()

# %%
### You can use the axis parameter in the grid() function to specify which grid lines to display.

### Legal values are: 'x', 'y', and 'both'. Default value is 'both'
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')          ### Grid is introduced along the x axis only

plt.show()

# %%
### Display only grid lines for the y-axis
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
### Set Line Properties for the Grid
### You can also set the line properties of the grid, like this: grid
                 ### (color = 'color', linestyle = 'linestyle', linewidth = number).
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
### Create a Plot for Price of a house with x-axis as Square ft and y-axis as Price in lacs 
xpoints=np.array([1000,2000,3000,5000])
ypoints=np.array([1,2,3,5])
plt.xlabel("Squre ft")
plt.ylabel("Price in lacs")
plt.title("Price of a house",loc="center")
plt.grid(color="brown")
plt.plot(xpoints,ypoints,"o:g")
plt.show()

# %%
#plot 1:
x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 2, 11])

plt.subplot(1, 2, 1)                 ### subplot function shows the plot for 1 Row and 2 Column and 1st plot
plt.plot(x,y)

#plot 2:
x = np.array([1, 2, 3, 4])
y = np.array([20, 30, 40, 50])

plt.subplot(1, 2, 2)                ### subplot function shows the plot for 1 Row and 2 Column 2nd plot
plt.plot(x,y)

plt.show()                          ### Two plot displayed in 1 Row and 2 Column

# %% [markdown]
# ### The subplots() function takes three arguments that describes the layout of the figure.
#
# ### The layout is organized in rows and columns, which are represented by the first and second argument.
#
# ### The third argument represents the index of the current plot.
# plt.subplot(1, 2, 1)
# #the figure has 1 row, 2 columns, and this plot is the first plot.
# plt.subplot(1, 2, 2)
# #the figure has 1 row, 2 columns, and this plot is the second plot.

# %%
#plot 1:
x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 2, 11])

plt.subplot(2, 1, 1)               ### subplot function shows the plot for 2 Row and 1 Column and 1st plot
plt.plot(x,y)

#plot 2:
x = np.array([1, 2, 3, 4])
y = np.array([20, 30, 40, 50])

plt.subplot(2, 1, 2)              ### subplot function shows the plot for 2 Row and 1 Column 2nd plot
plt.plot(x,y)

plt.show()                        ### Two plot displayed in 2 Row and 1 Column

# %%
x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 2, 11])

plt.subplot(2, 3, 1)                 ### subplot function shows the plot for 2 Row and 3 Column and 1st plot
plt.plot(x,y)

x = np.array([1, 2, 3, 4])
y = np.array([20, 30, 40, 50])

plt.subplot(2, 3, 2)                ### subplot function shows the plot for 2 Row and 3 Column and 2nd plot
plt.plot(x,y)

x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 2, 11])

plt.subplot(2, 3, 3)               ### subplot function shows the plot for 2 row and 3 column and 3rd plot
plt.plot(x,y)

x = np.array([1, 2, 3, 4])
y = np.array([20, 30, 40, 50])

plt.subplot(2, 3, 4)              ### subplot function shows the plot for 2 Row and 3 Column and 4th plot
plt.plot(x,y)

x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 2, 11])

plt.subplot(2, 3, 5)              ### subplot function shows the plot for 2 Row and 3 Column and 5th plot
plt.plot(x,y)

x = np.array([1, 2, 3, 4])
y = np.array([20, 30, 40, 50])

plt.subplot(2, 3, 6)              ### subplot function shows the plot for 2 Row and 3 Column and 6th plot
plt.plot(x,y)

plt.show()                        ### 6 plots displayed in 2 Row and 3 Column

# %%
### You can add a title to each plot with the title() function
x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 2, 11])

plt.subplot(1, 2, 1)             ### subplot function shows the plot for 2 Row and 3 Column and 1st plot

plt.plot(x,y) 
plt.title("SALES")                ### Title is Sales for 1st plot

#plot 2:
x = np.array([1, 2, 3, 4])
y = np.array([20, 30, 40, 50])

plt.subplot(1, 2, 2)
plt.plot(x,y)                 ### subplot function shows the plot for 2 Row and 3 Column and 2nd plot
plt.title("INCOME")             ### Title is Income for 2nd plot
 
plt.show()                      ### Plots are displayed

# %%
### You can add a title to the entire figure with the suptitle() function:
#plot 1:
x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 2, 11])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([1, 2, 3, 4])
y = np.array([20, 30, 40, 50])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
### With Pyplot, you can use the scatter() function to draw a scatter plot.

## The scatter() function plots one dot for each observation. It needs two arrays of the same length, 
## one for the values of the x-axis, and one for values on the y-axis.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# The observation in the example above is the result of 13 cars passing by.
#
# The X-axis shows how old the car is.
#
# The Y-axis shows the speed of the car when it passes.
#
# Are there any relationships between the observations?
#
# It seems that the newer the car, the faster it drives, but that could be a coincidence, after all we only registered 13 cars.

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
### By comparing the two plots, I think it is safe to say that they both gives us the same conclusion
###  the newer the car, the faster it drives
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
### You can even set a specific color for each dot by using an array of colors as value for the c argument.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
# ColorMap
## The Matplotlib module has a number of available colormaps.

### A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.

#### Here is an example of a colormap:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
### You can include the colormap in the drawing by including the plt.colorbar() statement
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)         ### size of plot is increased using s=sizes

plt.show()

# %%
### Alpha :You can adjust the transparency of the dots with the alpha argument.

### Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.1)

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([4, 9,2,11])

plt.bar(x,y)                           ### Bar graph is plotted
plt.show()

# %%
### The bar() function takes arguments that describes the layout of the bars.

### The categories and their values represented by the first and second argument as arrays.
x = ["A", "B"]
y = [5, 4]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
### If you want the bars to be displayed horizontally instead of vertically, use the barh() function.
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([4, 9, 2, 11])

plt.barh(x, y)
plt.show()

# %%
### The bar() and barh() takes the keyword argument color to set the color of the bars
x = np.array(["A", "B", "C", "D"])
y = np.array([4, 9, 2, 11])

plt.bar(x, y, color = "red")
plt.show()

# %%
### The bar() and barh() takes the keyword argument color to set the color of the bars
x = np.array(["A", "B", "C", "D"])
y = np.array([4, 9, 2, 11])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
### The bar() and barh() takes the keyword argument color to set the color of the bars
x = np.array(["A", "B", "C", "D"])
y = np.array([4, 9, 2, 11])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
## The bar() takes the keyword argument width to set the width of the bars
x = np.array(["A", "B", "C", "D"])
y = np.array([4, 9, 2, 11])

plt.bar(x, y, width = 0.5)             
plt.show()

# %%
## The barh() takes the keyword argument height to set the height of the bars
x = np.array(["A", "B", "C", "D"])
y = np.array([4, 9, 2, 11])

plt.barh(x, y, height = 0.1)   
plt.show()

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [150.36414255 164.63317941 179.60073914 171.39515352 157.48994532
#  170.5734667  158.2288252  167.86401282 171.83493184 162.4845557
#  186.38685975 152.61303133 162.31992769 165.68019608 175.45704583
#  170.17908712 180.54021137 161.02352558 169.15695718 147.87656588
#  179.32178592 162.12683424 167.6646255  171.39541021 191.94780118
#  170.08786771 152.01229739 168.49557068 183.07006911 172.58565618
#  174.63370539 184.09735509 161.07959842 166.87590724 181.5185915
#  174.58735078 167.94491901 180.88767038 183.52661528 170.47969748
#  167.60368987 169.90591025 167.60701151 177.91842152 168.54643972
#  167.9952801  169.42408326 165.51644029 158.04728177 164.06421296
#  181.03922313 164.29380139 168.60891968 171.06323068 167.64024615
#  179.37024336 156.78024869 168.25853899 174.70543816 175.46020168
#  163.82266068 165.02920457 155.19185397 166.25986731 168.95448973
#  163.28353363 170.59573319 188.97197261 175.62905329 166.57276258
# ...

# %%
### The hist() function takes arguments that describes the layout of the histogram.
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
### The pie() function takes arguments that describes the layout of the pie chart.
y = np.array([45, 35, 35, 25])

plt.pie(y)
plt.show()

# %%
### Add labels to the pie chart with the label parameter.

### The label parameter must be an array with one label for each wedge
y = np.array([45, 35, 35, 25])
mylabels = ["Mangoes", "Cashews", "Cherries", "Almonds"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
### As mentioned the default start angle is at the x-axis, but you can change the start angle 
### by specifying a startangle parameter.

### The startangle parameter is defined with an angle in degrees, default angle is 0:
y = np.array([45, 35, 35, 25])
mylabels = ["Mangoes", "Cashews", "Cherries", "Almonds"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
### The explode parameter is defined to segregate the plots
y = np.array([45, 35, 35, 25])
mylabels = ["Mangoes", "Cashews", "Cherries", "Almonds"]
myexplode = [0.2, 0.8, 0.1, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
### The color parameter is defined to change the colors of the pie plot
y = np.array([45, 35, 35, 25])
mylabels = ["Mangoes", "Cashews", "Cherries", "Almonds"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
### The legend() function is defined for the tagging of the pie plot
y = np.array([45, 35, 35, 25])
mylabels = ["Mangoes", "Cashews", "Cherries", "Almonds"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()
